# %%
from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.datasets import cifar10
from keras.utils import to_categorical
from keras.optimizers import Adam
import matplotlib.pyplot as plt
import numpy as np

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 136s 1us/step

# %%
X_train = X_train.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0
y_test=to_categorical(y_test)

# %%
model= Sequential()
model.add(Flatten(input_shape=(32, 32, 3)))
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
result=model.fit(X_train, to_categorical(y_train), epochs=10, batch_size=64 , validation_split=0.2)
# Out:
# Epoch 1/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.2373 - loss: 2.0547 - val_accuracy: 0.2773 - val_loss: 1.9659
# Epoch 2/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.3120 - loss: 1.8940 - val_accuracy: 0.3278 - val_loss: 1.8749
# Epoch 3/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.3404 - loss: 1.8333 - val_accuracy: 0.3466 - val_loss: 1.8206
# Epoch 4/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.3550 - loss: 1.7876 - val_accuracy: 0.3645 - val_loss: 1.7872
# Epoch 5/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.3717 - loss: 1.7472 - val_accuracy: 0.3670 - val_loss: 1.7570
# Epoch 6/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.3797 - loss: 1.7149 - val_accuracy: 0.3828 - val_loss: 1.7243
# Epoch 7/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.3904 - loss: 1.6868 - val_accuracy: 0.3912 - val_loss: 1.6956
# Epoch 8/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.3977 - loss: 1.6644 - val_accuracy: 0.3910 - val_loss: 1.6894
# Epoch 9/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.4089 - loss: 1.6398 - val_accuracy: 0.3974 - val_loss: 1.6691
# Epoch 10/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.4153 - loss: 1.6189 - val_accuracy: 0.4142 - val_loss: 1.6442

# %%
#visualization
plt.plot(result.history['val_accuracy'],label='Validation accuracy',color="blue")
plt.plot(result.history['accuracy'],label='Train accuracy',color="green")
plt.title("Train_accuracy vs Val_accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()


plt.plot(result.history['val_loss'],label='Validation loss',color="blue")
plt.plot(result.history['loss'],label='Train loss',color="green")
plt.title("Train_loss vs Val_loss")
plt.xlabel("Epochs")
plt.ylabel("loss")
plt.legend()
plt.show()
